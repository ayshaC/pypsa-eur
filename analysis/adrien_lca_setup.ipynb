# %%
# # This notebook can fetch ecoinvent data. It requires an environment with the following installed:
# name: premise
# channels:
#     - conda-forge
# dependencies:
#     - python=3.11
#     - ipdb=0.13.13 # replaces default debugger with IPython debugger
#     - pip:
#       - premise[bw2]
#       - openpyxl

# + run the notebook

# %%
import bw2data as bd
import bw2io as bi
from premise import *
# Out:
# 2026-07-07T11:35:10.384060Z [warning  ] Brightway not installed; Brightway IO functionality disabled [wurst]

# %% [markdown]
# # Importing ecoinvent

# %%
# Set up your Brightway project first.
# For this student, we had called it 'premise-data-ba' but you can call it whatever you want or have multiple projects.

print(
    f"Existing BD databases in project {'premise-data-students-test'} :",
    bd.databases,
    "\n",
)
# Out:
# Existing BD databases in project premise-data-students-test : Databases dictionary with 1 object(s):
# 	biosphere3

# %%
bd.databases
# Out:
# Databases dictionary with 1 object(s):
# 	biosphere3

# %%
bd.projects.set_current("premise-data-students-test")

ecoinvent_version = "3.10"
ecoinvent_system_model = "cutoff"

if f"ecoinvent-{ecoinvent_version}-{ecoinvent_system_model}" in bd.databases:
    print(
        f"Database ecoinvent-{ecoinvent_version}-{ecoinvent_system_model} already exists"
    )
else:
    # setup ecoinvent database
    # you can also use these credentials to check things online @ https://ecoquery.ecoinvent.org/3.11/cutoff 
    username = "studentethz"
    password = "gD4k{3e0#v|6"
    ecoinvent_biosphere_name = "biosphere"

    bi.import_ecoinvent_release(
        version=ecoinvent_version,
        system_model=ecoinvent_system_model,
        username=username,
        password=password,
        biosphere_name=ecoinvent_biosphere_name,
    )
# Out:
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: ensure_categories_are_tuples
# Applied 3 strategies in 0.00 seconds
# 4362 datasets
# 0 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/07/2026 13:35:19
#   Finished: 07/07/2026 13:35:19
#   Total time elapsed: 00:00:00
#   CPU %: 99.50
#   Memory %: 2.74
# Created database: biosphere
# Extracting XML data from 23523 datasets
# Extracted 23523 datasets in 23.55 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: update_social_flows_in_older_consequential
# Applying strategy: set_lognormal_loc_value
# Applied 22 strategies in 4.25 seconds
# 23523 datasets
# 743409 exchanges
# 0 unlinked exchanges
#
# Warning: No valid output stream.
# Title: Writing activities to SQLite3 database:
#   Started: 07/07/2026 13:35:51
#   Finished: 07/07/2026 13:36:07
#   Total time elapsed: 00:00:16
#   CPU %: 95.60
#   Memory %: 21.29
# Created database: ecoinvent-3.10-cutoff

# %% [markdown]
# # Premise stuff

# %%
premise_models = ["remind"]
premise_pathways = ["SSP2-Base", "SSP2-PkBudg1150"]
premise_years = [2050, 2025]
premise_key = "tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo="

scenarios = [
    {"model": model, "pathway": pathway, "year": year}
    for model in premise_models
    for pathway in premise_pathways
    for year in premise_years
]

scenarios
# Out:
# [{'model': 'remind', 'pathway': 'SSP2-Base', 'year': 2050},
#  {'model': 'remind', 'pathway': 'SSP2-Base', 'year': 2025},
#  {'model': 'remind', 'pathway': 'SSP2-PkBudg1150', 'year': 2050},
#  {'model': 'remind', 'pathway': 'SSP2-PkBudg1150', 'year': 2025}]

# %%
# The following two cells can take a while to run. Maybe start with one pathway and one year to check if things work correctly

# %%
ndb = NewDatabase(
    scenarios=scenarios,
    source_db=f"ecoinvent-{ecoinvent_version}-{ecoinvent_system_model}",
    source_version=ecoinvent_version,
    key=premise_key,
    biosphere_name=ecoinvent_biosphere_name,
)
# Out:
# Cannot find the IAM scenario file at /Users/jopeel/miniconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-Base. Will check online.
# Cannot find the IAM scenario file at /Users/jopeel/miniconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-Base. Will check online.
# Cannot find the IAM scenario file at /Users/jopeel/miniconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-PkBudg1150. Will check online.
# Cannot find the IAM scenario file at /Users/jopeel/miniconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-PkBudg1150. Will check online.
# premise v.(2, 4, 6)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# remind_SSP2-Base.csv not found locally. Downloading...
# Failed to download remind_SSP2-Base.csv. Status code: 404
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ndb = NewDatabase(
#       2     scenarios=scenarios,
#       3     source_db=f"ecoinvent-{ecoinvent_version}-{ecoinvent_system_model}",
#       4     source_version=ecoinvent_version,
#
# File ~/miniconda3/envs/premise/lib/python3.11/site-packages/premise/new_database.py:726, in NewDatabase.__init__(self, scenarios, source_version, source_type, key, source_db, source_file_path, additional_inventories, system_model, system_args, use_cached_inventories, use_cached_database, external_scenarios, quiet, keep_imports_uncertainty, keep_source_db_uncertainty, gains_scenario, use_absolute_efficiency, biosphere_name, generate_reports)
#     724 print("- Fetching IAM data")
#     725 for scenario in self.scenarios:
# --> 726     _fetch_iam_data(scenario)
#     728 print("Done!")
#
# File ~/miniconda3/envs/premise/lib/python3.11/site-packages/premise/new_database.py:662, in NewDatabase.__init__.<locals>._fetch_iam_data(scenario)
#     661 def _fetch_iam_data(scenario):
# --> 662     data = IAMDataCollection(
#     663         model=scenario["model"],
#     664         pathway=scenario["pathway"],
#     665         year=scenario["year"],
#     666         external_scenarios=scenario.get("external scenarios"),
#     667         filepath_iam_files=scenario["filepath"],
#     668         key=key,
#     669         system_model=self.system_model,
#     670         system_model_args=self.system_model_args,
#     671         gains_scenario=self.gains_scenario,
#     672         use_absolute_efficiency=self.use_absolute_efficiency,
#     673     )
#     674     scenario["iam data"] = data
#     676     if "external scenarios" in scenario:
#
# File ~/miniconda3/envs/premise/lib/python3.11/site-packages/premise/data_collection.py:610, in IAMDataCollection.__init__(self, model, pathway, year, filepath_iam_files, key, external_scenarios, system_model, system_model_args, gains_scenario, use_absolute_efficiency)
#     604 new_vars = flatten(new_vars)
#     606 # if "liquid fossil fuels" is in the list of fuel variables
#     607 # we add the split of gasoline, diesel, LPG and kerosene
#     608 # to `data`, because it means it's not already in the IAM file.
# --> 610 data = self.__get_iam_data(
#     611     key=key,
#     612     filedir=filepath_iam_files,
#     613     variables=new_vars,
#     614     split_fossil_liquid_fuels=(
#     615         {
#     616             k: v
#     617             for k, v in fuel_prod_vars.items()
#     618             if k
#     619             in [
#     620                 "gasoline",
#     621                 "diesel",
#     622                 "kerosene",
#     623                 "liquid fossil fuels",
#     624                 "heavy fuel oil",
#     625                 "liquefied petroleum gas",
#     626             ]
#     627         }
#     628         if "liquid fossil fuels" in fuel_prod_vars
#     629         else None
#     630     ),
#     631 )
#     633 self.data = data
#     635 self.regions = data.region.values.tolist()
#
# File ~/miniconda3/envs/premise/lib/python3.11/site-packages/premise/data_collection.py:1248, in IAMDataCollection.__get_iam_data(self, key, filedir, variables, split_fossil_liquid_fuels)
#    1246 if key is not None:
#    1247     fernet_obj = Fernet(key)
# -> 1248     with open(file_path, "rb") as file:
#    1249         encrypted_data = file.read()
#    1251     # Decrypt data
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jopeel/miniconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-Base.csv'

# %%
ndb.update()
ndb.write_db_to_brightway()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
